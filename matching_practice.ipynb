# %% [markdown]
# <a href="https://colab.research.google.com/github/jaredwool/causal_modeling/blob/main/matching_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jaredwool/causal_modeling.git
# !pip install kaggle
#!pip -qq install catboost
# !pip install pymalts2
# Out:
# Cloning into 'causal_modeling'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.

# %%
import pandas as pd
import pymalts2
import numpy as np

# %% [markdown]
# Data available from Kaggle.com at https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset?select=WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
# load the data into a pandas dataframe
df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Explore the data a little
df.shape
# Out:
# (1470, 35)

# %%
df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# Use Causal Discovery to find values that impact attrition.
# Out:
# fatal: not a git repository (or any of the parent directories): .git
